# %%
from manim import *

class SigninFunctionExplanation(Scene):
    def construct(self):
        # Title
        title = Text("async signin(): Handle User Authentication", font_size=30, color=WHITE)
        self.play(Write(title))
        self.play(title.animate.to_edge(UP))

        # JavaScript code for the signin function
        code = '''
async function signin() {
    const email = document.getElementById('signin-email').value;
    const password = document.getElementById('signin-password').value;
    const messageElement = document.getElementById('signin-message');

    try {
        const response = await fetch(`${API_URL}/signin`, {
            method: 'POST',
            headers: {
                'Content-Type': 'application/json'
            },
            body: JSON.stringify({ email, password })
        });

        const data = await response.json();
        if (response.ok) {
            messageElement.style.color = 'green';
            messageElement.innerText = data.message;
        } else {
            messageElement.style.color = 'red';
            messageElement.innerText = data.message;
        }
    } catch (error) {
        messageElement.style.color = 'red';
        messageElement.innerText = 'Sign in failed';
    }
}
'''.strip()

        # Render the JavaScript code
        rendered_code = Code(code=code, tab_width=4, background="window",
                             language="javascript", font="Monospace",
                             line_spacing=0.5, style="monokai")

        # Position the code below the title and align to the left
        rendered_code.scale(0.55).next_to(title, DOWN, buff=0.5).to_edge(LEFT)
        rendered_code.code = remove_invisible_chars(rendered_code.code)

        # Add the code to the scene
        self.play(Create(rendered_code))
        self.wait(1)

        # Explanation text for each step
        explanations = [
            "Async function declaration",
            "Get email and password input",
            "Prepare fetch request",
            "Send POST request to signin endpoint",
            "Handle successful authentication",
            "Handle unsuccessful authentication",
            "Catch and handle errors"
        ]

        # Create and position explanation text objects
        explanation_texts = [
            Text(exp, font_size=23, color=WHITE).next_to(rendered_code, RIGHT).shift(DOWN * (i) * 0.65).shift(UP*3)
            for i, exp in enumerate(explanations)
        ]

        # Define which lines to highlight for each explanation
        highlight_lines = [
            [0],    # Async function declaration
            [1, 2, 3], # Get email and password input
            [4, 5, 6, 7, 8], # Prepare fetch request
            [9],       # Send POST request
            [11, 12, 13], # Handle successful authentication
            [15, 16],     # Handle unsuccessful authentication
            [18, 19, 20]  # Catch and handle errors
        ]

        # Create highlight rectangles
        margin = 0.1
        highlight_rects = [
            Rectangle(
                width=rendered_code.width,
                height=0.26 * len(lines),
                color=YELLOW,
                fill_opacity=0.3
            ).align_to(rendered_code.code[lines[0]], UL).align_to(rendered_code, LEFT).shift(UP * margin / 2)
            for lines in highlight_lines
        ]

        # Animate highlights and explanations
        for rect, text in zip(highlight_rects, explanation_texts):
            self.play(
                FadeIn(rect),
                Write(text)
            )
            self.wait(2)
            self.play(
                FadeOut(rect),
            )
            self.wait(1)

        # Wait before finishing
        self.wait(2)
        self.play(FadeOut(title), FadeOut(rendered_code), *[FadeOut(text) for text in explanation_texts])

# Render the scene
# %manim -ql -v CRITICAL SigninFunctionExplanation
# Out:
# Manim Community v0.18.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 111
#     108         self.play(FadeOut(title), FadeOut(rendered_code), *[FadeOut(text) for text in explanation_texts])
#     110 # Render the scene
# --> 111 get_ipython().run_line_magic('manim', '-ql -v CRITICAL SigninFunctionExplanation')
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/utils/ipython_magic.py:143, in ManimMagic.manim(self, line, cell, local_ns)
#     141     SceneClass = local_ns[config["scene_names"][0]]
#     142     scene = SceneClass(renderer=renderer)
# --> 143     scene.render()
#     144 finally:
#     145     # Shader cache becomes invalid as the context is destroyed
#     146     shader_program_cache.clear()
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/scene/scene.py:229, in Scene.render(self, preview)
#     227 self.setup()
#     228 try:
# --> 229     self.construct()
#     230 except EndSceneEarlyException:
#     231     pass
#
# Cell In[2], line 52, in SigninFunctionExplanation.construct(self)
#      50 # Add the code to the scene
#      51 self.play(Create(rendered_code))
# ---> 52 self.wait(1)
#      54 # Explanation text for each step
#      55 explanations = [
#      56     "Async function declaration",
#      57     "Get email and password input",
#    (...)
#      62     "Catch and handle errors"
#      63 ]
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/scene/scene.py:1134, in Scene.wait(self, duration, stop_condition, frozen_frame)
#    1107 def wait(
#    1108     self,
#    1109     duration: float = DEFAULT_WAIT_TIME,
#    1110     stop_condition: Callable[[], bool] | None = None,
#    1111     frozen_frame: bool | None = None,
#    1112 ):
#    1113     """Plays a "no operation" animation.
#    1114
#    1115     Parameters
#    (...)
#    1132     :class:`.Wait`, :meth:`.should_mobjects_update`
#    1133     """
# -> 1134     self.play(
#    1135         Wait(
#    1136             run_time=duration,
#    1137             stop_condition=stop_condition,
#    1138             frozen_frame=frozen_frame,
#    1139         )
#    1140     )
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/scene/scene.py:1092, in Scene.play(self, subcaption, subcaption_duration, subcaption_offset, *args, **kwargs)
#    1089     return
#    1091 start_time = self.renderer.time
# -> 1092 self.renderer.play(self, *args, **kwargs)
#    1093 run_time = self.renderer.time - start_time
#    1094 if subcaption:
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/renderer/cairo_renderer.py:81, in CairoRenderer.play(self, scene, *args, **kwargs)
#      79     hash_current_animation = f"uncached_{self.num_plays:05}"
#      80 else:
# ---> 81     hash_current_animation = get_hash_from_play_call(
#      82         scene,
#      83         self.camera,
#      84         scene.animations,
#      85         scene.mobjects,
#      86     )
#      87     if self.file_writer.is_already_cached(hash_current_animation):
#      88         logger.info(
#      89             f"Animation {self.num_plays} : Using cached data (hash : %(hash_current_animation)s)",
#      90             {"hash_current_animation": hash_current_animation},
#      91         )
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/utils/hashing.py:357, in get_hash_from_play_call(scene_object, camera_object, animations_list, current_mobjects_list)
#     355 camera_json = get_json(camera_object)
#     356 animations_list_json = [get_json(x) for x in sorted(animations_list, key=str)]
# --> 357 current_mobjects_list_json = [get_json(x) for x in current_mobjects_list]
#     358 hash_camera, hash_animations, hash_current_mobjects = (
#     359     zlib.crc32(repr(json_val).encode())
#     360     for json_val in [camera_json, animations_list_json, current_mobjects_list_json]
#     361 )
#     362 hash_complete = f"{hash_camera}_{hash_animations}_{hash_current_mobjects}"
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/utils/hashing.py:322, in get_json(obj)
#     309 def get_json(obj: dict):
#     310     """Recursively serialize `object` to JSON using the :class:`CustomEncoder` class.
#     311
#     312     Parameters
#    (...)
#     320         The flattened object
#     321     """
# --> 322     return json.dumps(obj, cls=_CustomEncoder)
#
# File /usr/lib/python3.12/json/__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/utils/hashing.py:306, in _CustomEncoder.encode(self, obj)
#     304 if isinstance(obj, (dict, list, tuple)):
#     305     return super().encode(self._cleaned_iterable(obj))
# --> 306 return super().encode(obj)
#
# File /usr/lib/python3.12/json/encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File /usr/lib/python3.12/json/encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/utils/hashing.py:231, in _CustomEncoder.default(self, obj)
#     229     if isinstance(temp, MappingProxyType):
#     230         return "MappingProxy"
# --> 231     return self._cleaned_iterable(temp)
#     232 elif isinstance(obj, np.uint8):
#     233     return int(obj)
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/utils/hashing.py:288, in _CustomEncoder._cleaned_iterable(self, iterable)
#     286     return _iter_check_list(iterable)
#     287 elif isinstance(iterable, dict):
# --> 288     return _iter_check_dict(iterable)
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/utils/hashing.py:268, in _CustomEncoder._cleaned_iterable.<locals>._iter_check_dict(dct)
#     266 processed_dict = {}
#     267 for k, v in dct.items():
# --> 268     v = _Memoizer.check_already_processed(v)
#     269     if k in KEYS_TO_FILTER_OUT:
#     270         continue
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/utils/hashing.py:102, in _Memoizer.check_already_processed(cls, obj)
#      87 """Checks if obj has been already processed. Returns itself if it has not been,
#      88 or the value of _ALREADY_PROCESSED_PLACEHOLDER if it has.
#      89 Marks the object as processed in the second case.
#    (...)
#      99     Either the object itself or the placeholder.
#     100 """
#     101 # When the object is not memoized, we return the object itself.
# --> 102 return cls._handle_already_processed(obj, lambda x: x)
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/utils/hashing.py:136, in _Memoizer._handle_already_processed(cls, obj, default_function)
#     134 if isinstance(obj, collections.abc.Hashable):
#     135     try:
# --> 136         return cls._return(obj, hash, default_function)
#     137     except TypeError:
#     138         # In case of an error with the hash (eg an object is marked as hashable
#     139         # but contains a non hashable within it)
#     140         # Fallback to use the built-in function id instead.
#     141         pass
#
# File ~/DevTools/Manim/manDE/lib/python3.12/site-packages/manim/utils/hashing.py:144, in _Memoizer._return(cls, obj, obj_to_membership_sign, default_func, memoizing)
#     141             pass
#     142     return cls._return(obj, id, default_function)
# --> 144 @classmethod
#     145 def _return(
#     146     cls,
#     147     obj: typing.Any,
#     148     obj_to_membership_sign: typing.Callable[[Any], int],
#     149     default_func,
#     150     memoizing=True,
#     151 ) -> str | Any:
#     152     obj_membership_sign = obj_to_membership_sign(obj)
#     153     if obj_membership_sign in cls._already_processed:
#
# KeyboardInterrupt:

# %%
from manim import *

class SigninFunctionExplanation(Scene):
    def construct(self):
        # Title
        title = Text("async signup(): Handle User Registration", font_size=30, color=WHITE)
        self.play(Write(title))
        self.play(title.animate.to_edge(UP))

        # JavaScript code for the signup function
        code = '''
async function signin() {
    const email = document.getElementById('signin-email').value;
    const password = document.getElementById('signin-password').value;
    const messageElement = document.getElementById('signin-message');

    try {
        const response = await fetch(`${API_URL}/signin`, {
            method: 'POST',
            headers: {
                'Content-Type': 'application/json'
            },
            body: JSON.stringify({ email, password })
        });

        const data = await response.json();
        if (response.ok) {
            messageElement.style.color = 'green';
            messageElement.innerText = data.message;
        } else {
            messageElement.style.color = 'red';
            messageElement.innerText = data.message;
        }
    } catch (error) {
        messageElement.style.color = 'red';
        messageElement.innerText = 'Sign in failed';
    }
}
'''.strip()



        # Render the JavaScript code
        rendered_code = Code(code=code, tab_width=4, background="window",
                             language="javascript", font="Monospace",
                             line_spacing=0.5, style="monokai")

        # Position the code below the title and align to the left
        rendered_code.scale(0.55).next_to(title, DOWN, buff=0.5).to_edge(LEFT)
        rendered_code.code = remove_invisible_chars(rendered_code.code)

        # Add the code to the scene
        self.play(Create(rendered_code))
        self.wait(1)

        # Explanation text for each step
        # Explanation text for each step
        explanations = [
            "Async function declaration",
            "Get email and password input",
            "Prepare fetch request and\nSend POST request\nto signin endpoint",
            "Handle successful authentication",
            "Handle unsuccessful authentication",
            "Catch and handle errors"
        ]

        # Create and position explanation text objects
        explanation_texts = [
            Text(exp, font_size=23, color=WHITE).next_to(rendered_code, RIGHT).shift(DOWN * (i) * 0.9).shift(UP*3)
            for i, exp in enumerate(explanations)
        ]

        # Define which lines to highlight for each explanation
        highlight_lines = [
            [0],    # Async function declaration
            [1, 2, 3], # Get email and password input
            [4, 5, 6, 7, 8, 9], # Prepare fetch request and Send POST request
            [11, 12, 13], # Handle successful authentication
            [15, 16],     # Handle unsuccessful authentication
            [18, 19, 20]  # Catch and handle errors
        ]



        # Create highlight rectangles
        margin = 0.1
        highlight_rects = [
            Rectangle(
                width=rendered_code.width,
                height=0.26 * len(lines),
                color=YELLOW,
                fill_opacity=0.3
            ).align_to(rendered_code.code[lines[0]], UL).align_to(rendered_code, LEFT).shift(UP * margin / 2)
            for lines in highlight_lines
        ]

        # Animate highlights and explanations
        for rect, text in zip(highlight_rects, explanation_texts):
            self.play(
                FadeIn(rect),
                Write(text)
            )
            self.wait(2)
            self.play(
                FadeOut(rect),
            )
            self.wait(1)

        # Wait before finishing
        self.wait(2)
        self.play(FadeOut(title), FadeOut(rendered_code), *[FadeOut(text) for text in explanation_texts])

# Render the scene
# %manim -ql -v CRITICAL SigninFunctionExplanation
# Out:
# Manim Community v0.18.1
# <video src="media/jupyter/SigninFunctionExplanation@2024-10-02@10-47-43.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from manim import *

class SignupFunctionExplanation2(Scene):
    def construct(self):
        # Title
        title = Text("async signin(): Handle User Login", font_size=30, color=WHITE)
        self.play(Write(title))
        self.play(title.animate.to_edge(UP))

        # JavaScript code for the signup function
        code = '''
async function signin() {
    const email = document.getElementById('signin-email').value;
    const password = document.getElementById('signin-password').value;
    const messageElement = document.getElementById('signin-message');

    try {
        const response = await fetch(`${API_URL}/signin`, {
            method: 'POST',
            headers: {
                'Content-Type': 'application/json'
            },
            body: JSON.stringify({ email, password })
        });

        const data = await response.json();
        if (response.ok) {
            messageElement.style.color = 'green';
            messageElement.innerText = data.message;
        } else {
            messageElement.style.color = 'red';
            messageElement.innerText = data.message;
        }
    } catch (error) {
        messageElement.style.color = 'red';
        messageElement.innerText = 'Sign in failed';
    }
}
'''.strip()

        # Render the JavaScript code
        rendered_code = Code(code=code, tab_width=4, background="window",
                             language="javascript", font="Monospace",
                             line_spacing=0.5, style="monokai")

        # Position the code below the title and align to the left
        rendered_code.scale(0.55).next_to(title, DOWN, buff=0.5).to_edge(LEFT)
        rendered_code.code = remove_invisible_chars(rendered_code.code)

        # Add the code to the scene
        self.play(Create(rendered_code))
        self.wait(1)

        # Explanation text for each step
        explanations = [
            "Async function declaration",
            "Get input values from form",
            "Prepare fetch request and send\nPOST request to signup endpoint",
            "Handle successful response",
            "Handle unsuccessful response",
            "Catch and handle errors"
        ]

        # Create and position explanation text objects
        explanation_texts = [
            Text(exp, font_size=23, color=WHITE).next_to(rendered_code, RIGHT).shift(DOWN * (i) * 0.9).shift(UP*3)
            for i, exp in enumerate(explanations)
        ]

        # Define which lines to highlight for each explanation
        highlight_lines = [
            [0],    # Async function declaration
            [1, 2, 3], # Get input values from form
            [5, 6, 7, 8, 9, 10, 11], # Prepare fetch request and Send POST request
            [15, 16, 17], # Handle successful response
            [18, 19, 20],     # Handle unsuccessful response
            [22, 23, 24]      # Catch and handle errors
        ]

        # Create highlight rectangles
        margin = 0.1
        highlight_rects = [
            Rectangle(
                width=rendered_code.width,
                height=0.26 * len(lines),
                color=YELLOW,
                fill_opacity=0.3
            ).align_to(rendered_code.code[lines[0]], UL).align_to(rendered_code, LEFT).shift(UP * margin / 2)
            for lines in highlight_lines
        ]

        # Animate highlights and explanations
        for rect, text in zip(highlight_rects, explanation_texts):
            self.play(
                FadeIn(rect),
                Write(text)
            )
            self.wait(2)
            self.play(
                FadeOut(rect),
            )
            self.wait(1)

        # Wait before finishing
        self.wait(2)
        self.play(FadeOut(title), FadeOut(rendered_code), *[FadeOut(text) for text in explanation_texts])

# Render the scene
# %manim -qh -v CRITICAL SignupFunctionExplanation2
# Out:
# Manim Community v0.18.1
# <video src="media/jupyter/SignupFunctionExplanation2@2024-10-02@23-01-23.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
